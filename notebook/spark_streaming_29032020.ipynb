# %%
import findspark
findspark.init('/home/ubuntu/spark-2.4.5-bin-hadoop2.7')
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# %%
sc = SparkContext('local[2]', 'NetworkWordCount')
ssc = StreamingContext(sc, 5)

# %%
lines = ssc.socketTextStream('localhost', 9999)
words = lines.flatMap(lambda line: line.split(' '))
pairs = words.map(lambda word: (word,1))
word_counts = pairs.reduceByKey(lambda num1, num2: num1+num2)

# %%
word_counts.pprint()

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2020-03-29 11:03:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:03:15
# -------------------------------------------
# ('Hello', 1)
# ('World!', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:03:20
# -------------------------------------------
# ('World', 1)
# ('is', 1)
# ('down', 1)
# ('Lock', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:03:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:03:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:03:35
# -------------------------------------------
# ('Hello', 1)
# ('phone', 1)
# ('on', 1)
# ('web', 1)
# ('or', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:03:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:03:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:03:50
# -------------------------------------------
# ('new', 1)
# ('way', 1)
# ('communicate', 1)
# ('in', 1)
# ('World', 1)
# ('general', 1)
# ('to', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:03:55
# -------------------------------------------
# ('World', 1)
# ('countries', 1)
# ('In', 1)
# ('195', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:04:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:04:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:04:10
# -------------------------------------------
# ('Saying', 1)
# ('Hello', 1)
# ('Again', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:04:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:04:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:04:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:04:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-03-29 11:04:35
# -------------------------------------------
# ('Hello', 2)
# ('World', 2)
# ('test', 2)
# ('match', 1)
# ('Multiple', 1)
#
# -------------------------------------------
# Time: 2020-03-29 11:04:40
# -------------------------------------------

# %% [markdown]
# ### On command line
# - nc -lk 9999
# - Type sentenses in new lines

# %% [markdown]
# ### Result will be reflect on the notebook output cell
